# %%
import os
import cv2
import numpy as np
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from tensorflow.keras.models import load_model
import mediapipe as mp

# Load model and label encoder
model = load_model('asl_cnn_2D_model.h5')

with open("label_encoder.pickle", "rb") as f:
    label_encoder = pickle.load(f)

CLASS_NAMES = list(label_encoder.classes_)

# Mediapipe setup
mp_hands = mp.solutions.hands
hands = mp_hands.Hands(static_image_mode=True, min_detection_confidence=0.5)

# Image directory
IMAGE_FOLDER_PATH = r"ASL_Alphabet_Dataset\shreeshdataset"

# Storage
true_labels = []
predicted_labels = []

for image_name in os.listdir(IMAGE_FOLDER_PATH):
    image_path = os.path.join(IMAGE_FOLDER_PATH, image_name)

    if not image_name.lower().endswith(('.jpg', '.jpeg', '.png')):
        continue

    # Extract true label
    filename = os.path.splitext(image_name)[0]
    if "_" not in filename:
        print(f"Skipping file (no underscore): {image_name}")
        continue

    raw_label = filename.split('_')[0]
    true_label = ''.join([c for c in raw_label if not c.isdigit()])

    if true_label not in CLASS_NAMES:
        print(f"Skipping unknown class: {true_label} in {image_name}")
        continue
    
    

    # Read image
    image = cv2.imread(image_path)
    if image is None:
        print(f"Could not read image: {image_path}")
        continue
    
    
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    results = hands.process(image_rgb)

    if not results.multi_hand_landmarks:
        print(f"❌ No hand detected in: {image_name}")
        

    if results.multi_hand_landmarks:
        for hand_landmarks in results.multi_hand_landmarks:
            landmarks = []
            for point in hand_landmarks.landmark:
                landmarks.append(point.x)
                landmarks.append(point.y)

            if len(landmarks) < 42:
                print(f"Incomplete landmarks in {image_name}")
                continue

            input_data = np.array(landmarks[:42]).reshape(1, -1)
            prediction = model.predict(input_data)
            predicted_index = np.argmax(prediction, axis=1)[0]
            predicted_label = CLASS_NAMES[predicted_index]

            print(f"✅ {image_name} — True: {true_label}, Predicted: {predicted_label}")

            true_labels.append(true_label)
            predicted_labels.append(predicted_label)

# Accuracy & Confusion Matrix
if true_labels and predicted_labels:
    accuracy = accuracy_score(true_labels, predicted_labels)
    print(f"\n✅ Model Accuracy: {accuracy:.4f}")

    labels_sorted = sorted(set(true_labels + predicted_labels))
    cm = confusion_matrix(true_labels, predicted_labels, labels=labels_sorted)

    plt.figure(figsize=(12, 10))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels_sorted, yticklabels=labels_sorted)
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.title("Confusion Matrix - ASL MLP Model (Shreesh)")
    plt.xticks(rotation=45)
    plt.tight_layout()
    plt.show()
    print("\n📋 Classification Report:")
    print(classification_report(true_labels, predicted_labels, labels=labels_sorted))
else:
    print("❌ No valid predictions were made.")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# ✅ A1_test.jpg — True: A, Predicted: A
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# ✅ A2_test.jpg — True: A, Predicted: A
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# ✅ A_test.jpg — True: A, Predicted: A
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# ✅ B1_test.jpg — True: B, Predicted: B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# ✅ B2_test.jpg — True: B, Predicted: B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# ✅ B_test.jpg — True: B, Predicted: B
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# ✅ C1_test.jpg — True: C, Predicted: C
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# ✅ C2_test.jpg — True: C, Predicted: C
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# ✅ C_test.jpg — True: C, Predicted: C
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# ✅ D1_test.jpg — True: D, Predicted: D
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# ✅ D2_test.jpg — True: D, Predicted: D
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# ✅ del1_test.jpg — True: del, Predicted: del
# ❌ No hand detected in: del2_test.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# ✅ D_test.jpg — True: D, Predicted: D
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# ✅ E1_test.jpg — True: E, Predicted: E
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# ✅ E2_test.jpg — True: E, Predicted: E
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# ✅ E_test.jpg — True: E, Predicted: E
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# ✅ F1_test.jpg — True: F, Predicted: F
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# ✅ F2_test.jpg — True: F, Predicted: F
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# ✅ F_test.jpg — True: F, Predicted: F
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# ✅ G1_test.jpg — True: G, Predicted: G
# ❌ No hand detected in: G2_test.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# ✅ G_test.jpg — True: G, Predicted: P
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# ✅ H1_test.jpg — True: H, Predicted: H
# ❌ No hand detected in: H2_test.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# ✅ H_test.jpg — True: H, Predicted: H
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# ✅ I1_test.jpg — True: I, Predicted: I
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# ✅ I2_test.jpg — True: I, Predicted: Y
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# ✅ I_test.jpg — True: I, Predicted: Y
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# ✅ J1_test.jpg — True: J, Predicted: S
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# ✅ J2_test.jpg — True: J, Predicted: Y
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# ✅ J_test.jpg — True: J, Predicted: Y
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# ✅ K1_test.jpg — True: K, Predicted: V
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# ✅ K2_test.jpg — True: K, Predicted: V
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# ✅ K_test.jpg — True: K, Predicted: K
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# ✅ L1_test.jpg — True: L, Predicted: L
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# ✅ L2_test.jpg — True: L, Predicted: L
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# ✅ L_test.jpg — True: L, Predicted: L
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# ✅ M1_test.jpg — True: M, Predicted: M
# ❌ No hand detected in: M2_test.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# ✅ M_test.jpg — True: M, Predicted: S
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# ✅ N1_test.jpg — True: N, Predicted: N
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# ✅ N2_test.jpg — True: N, Predicted: T
# Skipping unknown class: nothing in nothing1_test.jpg
# Skipping unknown class: nothing in nothing2_test.jpg
# Skipping unknown class: nothing in nothing_test.jpg
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# ✅ N_test.jpg — True: N, Predicted: S
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# ✅ O1_test.jpg — True: O, Predicted: O
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# ✅ O2_test.jpg — True: O, Predicted: O
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# ✅ O_test.jpg — True: O, Predicted: F
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# ✅ P1_test.jpg — True: P, Predicted: P
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# ✅ P2_test.jpg — True: P, Predicted: P
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# ✅ P_test.jpg — True: P, Predicted: Q
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# ✅ Q1_test.jpg — True: Q, Predicted: N
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# ✅ Q2_test.jpg — True: Q, Predicted: Q
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# ✅ Q_test.jpg — True: Q, Predicted: Q
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# ✅ R1_test.jpg — True: R, Predicted: R
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# ✅ R2_test.jpg — True: R, Predicted: R
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# ✅ R_test.jpg — True: R, Predicted: R
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# ✅ S1_test.jpg — True: S, Predicted: S
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# ✅ S2_test.jpg — True: S, Predicted: S
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# ✅ space1_test.jpg — True: space, Predicted: space
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# ✅ space2_test.jpg — True: space, Predicted: space
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# ✅ space_test.jpg — True: space, Predicted: space
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# ✅ S_test.jpg — True: S, Predicted: S
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# ✅ T1_test.jpg — True: T, Predicted: A
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# ✅ T2_test.jpg — True: T, Predicted: T
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# ✅ T_test.jpg — True: T, Predicted: S
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# ✅ U1_test.jpg — True: U, Predicted: U
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# ✅ U2_test.jpg — True: U, Predicted: U
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# ✅ U_test.jpg — True: U, Predicted: U
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# ✅ V1_test.jpg — True: V, Predicted: U
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# ✅ V2_test.jpg — True: V, Predicted: V
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# ✅ V_test.jpg — True: V, Predicted: V
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# ✅ W1_test.jpg — True: W, Predicted: W
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# ✅ W2_test.jpg — True: W, Predicted: W
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# ✅ W_test.jpg — True: W, Predicted: W
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# ✅ X1_test.jpg — True: X, Predicted: X
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# ✅ X2_test.jpg — True: X, Predicted: X
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# ✅ X_test.jpg — True: X, Predicted: X
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# ✅ Y1_test.jpg — True: Y, Predicted: I
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# ✅ Y2_test.jpg — True: Y, Predicted: Y
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# ✅ Y_test.jpg — True: Y, Predicted: Y
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# ✅ Z1_test.jpg — True: Z, Predicted: R
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# ✅ Z2_test.jpg — True: Z, Predicted: G
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# ✅ Z_test.jpg — True: Z, Predicted: Z
#
# ✅ Model Accuracy: 0.7468
# 📋 Classification Report:
#               precision    recall  f1-score   support
#
#            A       0.75      1.00      0.86         3
#            B       1.00      1.00      1.00         3
#            C       1.00      1.00      1.00         3
#            D       1.00      1.00      1.00         3
#            E       1.00      1.00      1.00         3
#            F       0.75      1.00      0.86         3
#            G       0.50      0.50      0.50         2
#            H       1.00      1.00      1.00         2
#            I       0.50      0.33      0.40         3
#            J       0.00      0.00      0.00         3
#            K       1.00      0.33      0.50         3
#            L       1.00      1.00      1.00         3
#            M       1.00      0.50      0.67         2
#            N       0.50      0.33      0.40         3
#            O       1.00      0.67      0.80         3
#            P       0.67      0.67      0.67         3
#            Q       0.67      0.67      0.67         3
#            R       0.75      1.00      0.86         3
#            S       0.43      1.00      0.60         3
#            T       0.50      0.33      0.40         3
#            U       0.75      1.00      0.86         3
#            V       0.50      0.67      0.57         3
#            W       1.00      1.00      1.00         3
#            X       1.00      1.00      1.00         3
#            Y       0.33      0.67      0.44         3
#            Z       1.00      0.33      0.50         3
#          del       1.00      1.00      1.00         1
#        space       1.00      1.00      1.00         3
#
#     accuracy                           0.75        79
#    macro avg       0.77      0.75      0.73        79
# weighted avg       0.76      0.75      0.73        79
# C:\Users\shree\AppData\Roaming\Python\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\shree\AppData\Roaming\Python\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\shree\AppData\Roaming\Python\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
